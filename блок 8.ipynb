# %%
M = int(input('Введите m: '))
N = int(input('Введите n: '))
matrix = []
for i in range(M):
    row = []
    for j in range(N):
        num = int(input('Введите число: '))
        row.append(num)
    matrix.append(row)

print('Созданная матрица:')
for i in range(M):
    for j in range(N):
        print(matrix[i][j] ,end=" ")
    print()

result = 0
for j in range(N): 
    all_odd = True    
    for i in range(M):  
        if matrix[i][j] % 2 == 0:  
            all_odd = False
            print(' в столбце',j+1,'Найден четный')
            break
    
    if all_odd:  
        result = j + 1  
        print(' В столбце',j+1,' ВСЕ НЕЧЕТНЫЕ!')
        break
if result==0 :
   print ('нет такого столбца ')
else:
   print('Финальный результат:=', result)
# Out:
# Введите m:  2
# Введите n:  2
# Введите число:  1
# Введите число:  2
# Введите число:  3
# Введите число:  4
# Созданная матрица:
# 1 2
# 3 4
#  В столбце 1  ВСЕ НЕЧЕТНЫЕ!
# Финальный результат:= 1

# %%
M = int(input('Введите m: '))
N = int(input('Введите n: '))
matrix = []
for i in range(M):
    row=[]
    for j in range (N):
        num=int(input('введите число '))
        row.append(num)
    matrix.append(row)
print ('полученная матрица ')
for i in range (M):
    for j in range(N):
      print (matrix[i][j], end=' ')
    print()
for i in range (M):
    min_val = min(matrix[i])
    max_val = max(matrix[i])
    min_index = matrix[i].index(min_val)
    max_index = matrix[i].index(max_val)
    matrix[i][min_index], matrix[i][max_index] = matrix[i][max_index], matrix[i][min_index]
print('Преобразованная матрица:')
for i in range(M):
    for j in range(N):
        print(matrix[i][j], end=' ')
    print()
# Out:
# Введите m:  3
# Введите n:  3
# введите число  1
# введите число  2
# введите число  3
# введите число  4
# введите число  5
# введите число  6
# введите число  7
# введите число  8
# введите число  10
# полученная матрица
# 1 2 3
# 4 5 6
# 7 8 10
# Преобразованная матрица:
# 3 2 1
# 6 5 4
# 10 8 7

# %%
M = int(input('Введите m: '))
N = int(input('Введите n: '))
matrix=[]
for i in range (M):
    row=[]
    for j in range(N):
       num =int(input('введите число'))
       row.append (num)
    matrix.append(row)
print ('полученная матрица ')
for i in range (M):
    for j in range (N):
       print (matrix[i][j], end=' ')
    print()
    
min_val = matrix[0][0]
max_val = matrix[0][0]
min_row = 0
max_row = 0
for i in range(M):
    for j in range(N):
        if matrix[i][j] < min_val:
            min_val = matrix[i][j]
            min_row = i
        if matrix[i][j] > max_val:
            max_val = matrix[i][j]
            max_row = i
if min_row != max_row:
    matrix[min_row], matrix[max_row] = matrix[max_row], matrix[min_row]
    print('Строки поменяны местами!')
else:
    print('Минимальный и максимальный элементы в одной строке - менять нечего')

print('Преобразованная матрица:')
for i in range(M):
    for j in range(N):
        print(matrix[i][j], end=' ')
    print()
# Out:
# Введите m:  3
# Введите n:  3
# введите число 1
# введите число 2
# введите число 3
# введите число 4
# введите число 5
# введите число 6
# введите число 7
# введите число 8
# введите число 9
# полученная матрица
# 1 2 3
# 4 5 6
# 7 8 9
# Строки поменяны местами!
# Преобразованная матрица:
# 7 8 9
# 4 5 6
# 1 2 3

# %%
M = int(input('Введите m: '))
N = int(input('Введите n: '))
matrix=[]
for i in range (M):
    row=[]
    for j in range(N):
       num =int(input('введите число'))
       row.append (num)
    matrix.append(row)
print ('полученная матрица ')
for i in range (M):
    for j in range (N):
       print (matrix[i][j], end=' ')
    print()

for i in range(M // 2):  
    matrix[i], matrix[M-1-i] = matrix[M-1-i], matrix[i]

print('Зеркально отраженная матрица:')
for i in range(M):
    for j in range(N):
        print(matrix[i][j], end=' ')
    print()
# Out:
# Введите m:  3
# Введите n:  3
# введите число 1
# введите число 2
# введите число 3
# введите число 4
# введите число 5
# введите число 6
# введите число 7
# введите число 8
# введите число 9
# полученная матрица
# 1 2 3
# 4 5 6
# 7 8 9
# Зеркально отраженная матрица:
# 7 8 9
# 4 5 6
# 1 2 3

# %%
m = int(input('кольчество строк'))
n = int(input('количество столбцов'))
mat = []
print("Введите элементы матрицы построчно:")
for i in range(m):
    el = list(map(int, input().split()))
    mat.append(el)

print(mat)

mn=100

for i in range(m):
    if min(mat[i])<mn:
        mn=min(mat[i])
        ix=i
del mat[ix]
        
print(mat)

# %%
m = int(input('кольчество строк'))
n = int(input('количество столбцов'))
mat = []
print("Введите элементы матрицы построчно:")
for i in range(m):
    el = list(map(int, input().split()))
    mat.append(el)

print(mat)

mn=100

for i in range(m):
    if min(mat[i])<mn:
        mn=min(mat[i])
        ix=i
del mat[ix]
        
print(mat)

# %%
m = int(input('кольчество строк'))
n = int(input('количество столбцов'))
mat = []
print("Введите элементы матрицы построчно:")
for i in range(m):
    el = list(map(int, input().split()))
    mat.append(el)

print(mat)
k=1
for i in range(m//2):
    l=len(mat[i])
    t= mat[i][i]
    mat[i][i]=mat[i][l-k]
    mat[i][l-k]= t
    k+=1
    
        
print(mat)
