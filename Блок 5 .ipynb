# %%
sum=0
n=int(input('введите n'))
for x in range (1,n+1):
    sum+=1/2**x
print ('сумма=',sum)
# Out:
# введите n 2
# сумма= 0.75

# %%
import math
sum=0
n=int(input('введите n'))
x=float(input('введите x'))
for i in range (1,n+1):
    sum+=(math.cos( x))**i/i
print ('сумма=',sum)
# Out:
# введите n 3
# введите x 0
# сумма= 1.8333333333333333

# %%
n=int(input('введите n'))
sum=0
for i in range (0,n+1):
    sum+=(-1)**n*3**n
print ('сумма=',sum)
# Out:
# введите n 0
# сумма= 1

# %%
import math
n=int(input('введите n'))
sum=0
for i in range (1,n+1):
    sum+=(1/math.sin(i))
print ('сумма=',sum)
# Out:
# введите n 1
# сумма= 1.1883951057781212

# %%
import math
n=int(input('введите n'))
sum=0
for i in range (1,n+1):
    sum+=(-1)**(i+1)*i**3
print ('сумма=',sum)
# Out:
# введите n 4
# сумма= -44

# %%
import math
sum=0
n=int(input('введите n'))
for i in range (1,n+1):
    sum+=(-1)**(i+1) * math.cos(i)
print ('сумма=',sum)
# Out:
# введите n 2
# сумма= 0.9564491424152821

# %%
import math
sum=0
n=int(input('введите n'))
x=float(input('введите x'))
for i in range (1,n+1):
  sum+=((-1)**(i-1) *x**i)/i
print ('сумма=',sum)
# Out:
# введите n 3
# введите x 0.5
# сумма= 0.4166666666666667

# %%
import math
sum=0
n=int(input('введите n'))
for i in range (1,n+1):
   sum+=(-1)**(i+1) * math.factorial(i)
print ('сумма=',sum)
# Out:
# введите n 4
# сумма= -19

# %%
import math
sum=0
n=int(input('введите n'))
x=float(input('введите x'))
for i in range (1,n+1):
    sum+=math.sin (x**i)
print ('сумма=',sum)
# Out:
# введите n 1
# введите x 0.5
# сумма= 0.479425538604203

# %%
import math
sum=0
n=int(input('введите n'))
for i in range (1,n+1):
    sum+=1/math.factorial(i)
print ('сумма=',sum)
# Out:
# введите n 4
# сумма= 1.7083333333333335

# %%
import math
sum=0
n=int(input('введите n'))
for x in range (n,(2*n)+1):
    sum+=x**2
print ('сумма=',sum)
# Out:
# введите n 3
# сумма= 86

# %%
import math
sum=0
n=int(input('введите n'))
for x in range (1,n+1):
    sum+=math.factorial (x)
print ('сумма=',sum)
# Out:
# введите n 5
# сумма= 153

# %%
import math
sum=0
x=float(input('введите x'))
n=int(input('введите n'))
for i in range (0,n+1):
    sum+=(x**i)/math.factorial(i)
print ('сумма=',sum)
# Out:
# введите x 1
# введите n 3
# сумма= 2.6666666666666665

# %%
x=float(input('введите x'))
n=int(input('введите n'))
sum=0
for i in range (0,n+1):
    sum+=(-1)**i * x**i
print ('сумма=',sum)
# Out:
# введите x 2
# введите n 3
# сумма= -5.0

# %%
x=float(input('введите x'))
n=int(input('введите n'))
sum=0
for i in range (0,n+1):
    sum+=(-1)**i * ((x**(2*i+1) /(2*i+1)))
print ('сумма=',sum)
# Out:
# введите x 0.5
# введите n 2
# сумма= 0.4645833333333333
