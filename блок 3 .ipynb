# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x > 0:
    print('y=',a*x**2+1)
else:
    print('y=',a*x-1)
# Out:
# введите a 2
# введите x -2
# y= -5.0

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >= 1:
    print('y=',a*x+1)
else:
    print('y=',x**2-1)
# Out:
# введите a 3
# введите x 0.5
# y= -0.75

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x < 0:
    print('y=',3*a**2)
else:
    print('y=',4*a*x-1)
# Out:
# введите a 2
# введите x -1
# y= 12.0

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >4:
    print('y=',2*a**2)
else:
    print('y=',3*x-1)
# Out:
# введите a 3
# введите x 2
# y= 5.0

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >2:
    print('y=',2*a*x-2)
else:
    print('y=',3*a**2-2*x)
# Out:
# введите a 2
# введите x 1
# y= 10.0

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >1:
    print('y=',2*a*x**2-1)
else:
    print('y=',x)
# Out:
# введите a 2
# введите x 0.5
# y= 0.5

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >2:
    print('y=',x**2)
else:
    print('y=',2*a-1)
# Out:
# введите a 3
# введите x 1
# y= 5.0

# %%
import math 
x=float(input('введите x'))
if x >2:
    print('y=',math.cos(2*x-1))
else:
    print('y=',math.sin(3*x+1))
# Out:
# введите x 3
# y= 0.28366218546322625

# %%
x=float(input('введите x'))
if x >2:
    print('y=',2*x**3-2*x-1)
else:
    print('y=',3*x**2-2*x+1)
# Out:
# введите x 1
# y= 2.0

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >1:
    print('y=',2*a*x**2-1)
elif a!=0:
    print('y=',1/a)
else:
    print ('деление на ноль ')
# Out:
# введите a 0
# введите x 0
# деление на ноль

# %%
import math
a=float(input('введите a'))
x=float(input('введите x'))
if x < 0:
    print('y=',a*x-1)
else:
    print('y=',a*math.sqrt(x)+1)
# Out:
# введите a -2
# введите x 1
# y= -1.0

# %%
import math
a=float(input('введите a'))
x=float(input('введите x'))
if x >=0:
    print('y=',math.sqrt(x)+a)
else:
    print('y=',a/x -1)
# Out:
# введите a 3
# введите x -2
# y= -2.5

# %%
a=float(input('введите a'))
x=float(input('введите x'))
if x >0:
    print('y=',1/x +a )
else:
    print('y=',x**2-1)
# Out:
# введите a 2
# введите x 4
# y= 2.25

# %%
import math
x=float(input('введите x'))
if x> math.pi/2:
    print ('y=',math.cos(x))
else:
    print('y=',math.sin(x))
# Out:
# введите x 1
# y= 0.8414709848078965

# %%
import math
x=float(input('введите x'))
if x>2 :
    print ('y=',math.sqrt(x-2))
else:
    print('y=',(x-2)**2 + 1)
# Out:
# введите x 1
# y= 2.0
