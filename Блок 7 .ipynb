# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append(num)
for x in range ( 0,n):
    if a[x]%2!=0:
        b.append(a[x])
if b==[]:
    print ('нет нечетных ')
else:
   b.sort(reverse=True)
   print(b)
# Out:
# введите n 4
# введите число  4
# введите число  8
# введите число  10
# введите число  12
# нет нечетных

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append(num)
for x in range (n):
    if a[x]>0:
        b.append(a[x])
if b==[]:
    print ('нет положительных ')
else:  
    b.sort()
    print (b)
# Out:
# введите n 5
# введите число  5
# введите число  2
# введите число  3
# введите число  4
# введите число  1
# [1, 2, 3, 4, 5]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append(num)
for x in range (n):
    if a[x]>0:
        b.append(a[x])
if b==[]:
    print ('нет положительных ')
else:  
    b.sort(reverse=True)
    print (b)
# Out:
# введите n 5
# введите число  2
# введите число  1
# введите число  4
# введите число  3
# введите число  7
# [7, 4, 3, 2, 1]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]%2==0:
        b.append([x])
if b==[]:
    print ('нет четных ')
else:          
    b.sort()
    print (b)
# Out:
# введите n 5
# введите число  3
# введите число  4
# введите число  2
# введите число  1
# введите число  5
# [2, 4]

# %%
a=[]
b=[]
n=int(input('введите n'))
k=int(input('введите k'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]>k:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:          
    b.sort(reverse=True)
    print (b)
# Out:
# введите n 5
# введите k 3
# введите число  6
# введите число  2
# введите число  3
# введите число  1
# введите число  4
# [6, 4]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]>10:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:          
    b.sort()
    print (b)
# Out:
# введите n 5
# введите число  10
# введите число  12
# введите число  3
# введите число  5
# введите число  17
# [12, 17]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append(num)
for x in range (n):
    if a[x]%5==0:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:          
    b.sort(reverse=True )
    print (b)
# Out:
# введите n 5
# введите число  1
# введите число  2
# введите число  1
# введите число  4
# введите число  2
# нет таких

# %%
a=[]
b=[]
n=int(input('введите n'))
k=int(input('введите k'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]<k:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort()
    print (b)
# Out:
# введите n 6
# введите k 3
# введите число  4
# введите число  6
# введите число  7
# введите число  1
# введите число  2
# введите число  3
# [1, 2]

# %%
a=[]
b=[]
n=int(input('введите n'))
k=int(input('введите k'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]<15:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort(reverse=True)
    print (b)
# Out:
# введите n 6
# введите k 18
# введите число  78
# введите число  3
# введите число  1
# введите число  12
# введите число  999
# введите число  56
# [12, 3, 1]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]%3==0:
       b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort()
    print (b)
# Out:
# введите n 6
# введите число  2
# введите число  6
# введите число  18
# введите число  2
# введите число  4
# введите число  3
# [3, 6, 18]

# %%
a=[]
b=[]
k=int(input('введите k'))
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]%k==0:
       b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort(reverse=True)
    print (b)
# Out:
# введите k 3
# введите n 6
# введите число  1
# введите число  6
# введите число  23
# введите число  18
# введите число  24
# введите число  12
# [24, 18, 12, 6]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]<0:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort()
    print (b)
# Out:
# введите n 5
# введите число  -5
# введите число  2
# введите число  -1
# введите число  12
# введите число  -8
# [-8, -5, -1]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (0,n,2):
    b.append(a[x])
b.sort(reverse=True)
print(b)
# Out:
# введите n 7
# введите число  1
# введите число  2
# введите число  3
# введите число  4
# введите число  5
# введите число  6
# введите число  7
# [7, 5, 3, 1]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (n):
    if a[x]>9 and a[x]<100:
        b.append(a[x])
if b==[]:
    print ('нет таких ')
else:
    b.sort()
    print (b)
# Out:
# введите n 8
# введите число  1
# введите число  23
# введите число  4
# введите число  56
# введите число  100
# введите число  300
# введите число  2
# введите число  13
# [13, 23, 56]

# %%
a=[]
b=[]
n=int(input('введите n'))
for x in range (n):
    num=int(input('введите число '))
    a.append (num)
for x in range (1,n,2):
    b.append(a[x])
b.sort()
print (b)
# Out:
# введите n 7
# введите число  12
# введите число  14
# введите число  5
# введите число  2
# введите число  6
# введите число  18
# введите число  97
# [2, 14, 18]
