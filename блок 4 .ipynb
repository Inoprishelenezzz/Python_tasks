# %%
k=int(input('введите число'))
n=int(input('введите n'))
for i in range (n):
    print(k)
# Out:
# введите число 1
# введите n 2
# 1.0
# 1.0

# %%
k=0
a=int(input('введите a '))
b=int(input('введите b'))
for x in range (a,b+1):
    k+=1
    print(x)
print('количество =', k)
# Out:
# введите a  2
# введите b 8
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# количество = 7

# %%
k=0
a=int(input('введите a '))
b=int(input('введите b'))
for x in range (b-1 ,a, -1):
   k+=1
   print('числа =',x)
print('количество =', k)
# Out:
# введите a  3
# введите b 8
# числа = 7
# числа = 6
# числа = 5
# числа = 4
# количество = 4

# %%
for x in range(1,11):
    print(20.4*x)
# Out:
# 20.4
# 40.8
# 61.199999999999996
# 81.6
# 102.0
# 122.39999999999999
# 142.79999999999998
# 163.2
# 183.6
# 204.0

# %%
a=int(input('введите a '))
b=int(input('введите b'))
h=int(input('введите h'))
for x in range ( a , b+1 , h):
    print(x**2)
# Out:
# введите a  1
# введите b 10
# введите h 2
# 1
# 9
# 25
# 49
# 81

# %%
a=int(input('введите a '))
b=int(input('введите b'))
h=int(input('введите h'))
for x in range ( a , b+1 , h):
    if x>0:
        print(x)
# Out:
# введите a  -3
# введите b 8
# введите h 2
# 1
# 3
# 5
# 7

# %%
sum=0
a=int(input('введите a '))
b=int(input('введите b'))
for x in range (a,b+1):
    sum+=x
print('сумма =',sum)
# Out:
# введите a  1
# введите b 5
# сумма = 15

# %%
pr=1
a=int(input('введите a '))
b=int(input('введите b'))
for x in range (a,b+1):
    pr*=x
print('произведение =',pr)
# Out:
# введите a  2
# введите b 4
# произведение = 24

# %%
sum=0
a=int(input('введите a '))
b=int(input('введите b'))
for x in range (a,b+1):
    sum+=x**2
print('сумма =',sum)

# %%
x=float(input('введите цену зa 1 кг'))
c=1.2
while (c<=2):
    print('цена за ',round(c,1) ,'кг=',c*x)
    c=c+0.2
# Out:
# введите цену зa 1 кг 150
# цена за  1.2 кг= 180.0
# цена за  1.4 кг= 210.0
# цена за  1.6 кг= 239.99999999999997
# цена за  1.8 кг= 270.0
# цена за  2.0 кг= 299.99999999999994

# %%
n=int(input('введите n '))
s=0
for x in range (1,2*n,2):
    s+=x
print(s)
# Out:
# введите n  4
# 16

# %%
a=float(input('введите a '))
n=int(input('введите n'))
for x in range(1,n+1):
    print (a**x  )
# Out:
# введите a  2
# введите n 4
# 2.0
# 4.0
# 8.0
# 16.0

# %%
n=int(input('введите n'))
k=0
while (k**2 <=n):
   k+=1
print (k-1)
# Out:
# введите n 17
# 4

# %%
n=int(input('введите n'))
k=0
while 3**k<n:
    k+=1
print(k-1)
# Out:
# введите n 10
# 2

# %%
n=int(input('введите n'))
a=float(input('введите a'))
b=float(input('введите b'))
h=(b-a)/n
print ('длина отрезка =', h )
for x in range (0,n+1):
    print(a+x*h)
# Out:
# введите n 3
# введите a 1
# введите b 4
# длина отрезка = 1.0
# 1.0
# 2.0
# 3.0
# 4.0
