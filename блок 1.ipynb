# %%
import math
x = float(input("Введите x: "))
result = 3 * x**2 + math.sin(x + 2)
print(f"y = {result}")
# Out:
# Введите x:  1
# y = 3.1411200080598674

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = a * x**2 + math.cos(2*x + 1)
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# y = 0.010007503399554585

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
b = float(input("Введите b: "))
result = a * x + b * math.sin(2*x + 2)
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  2
# Введите b:  1
# y = 1.2431975046920718

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = a * x**3 + math.cos(3*x + 1)
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  2
# y = 1.3463563791363882

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = x**2 / a + math.cos(2*x - 1)
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  2
# y = 1.0403023058681398

# %%
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = x / a + 2 * x**2
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# y = 3.0

# %%
x = float(input("Введите x: "))
result = 3 * x**2 - 2 * x + 1
print(f"y = {result}")
# Out:
# Введите x:  1
# y = 2.0

# %%
x = float(input("Введите x: "))
result = 0.5 * x**2 - 3 * x + 1
print(f"y = {result}")
# Out:
# Введите x:  1
# y = -1.5

# %%
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = 1 / (x**2 + 1) - a
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# y = -0.5

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
result = a / (x**2 + 1) - math.cos(2*x - 1)
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# y = -0.040302305868139654

# %%
x = float(input("Введите x: "))
result = x**3 - 2*x**2 + 4
print(f"y = {result}")
# Out:
# Введите x:  1
# y = 3.0

# %%
x = float(input("Введите x: "))
a = float(input("Введите a: "))
b = float(input("Введите b: "))
result = a*x**2 + b*x**3 - 8
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# Введите b:  1
# y = -6.0

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
b = float(input("Введите b: "))
result = a * math.sqrt(x**2 + 4) - b
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# Введите b:  1
# y = 1.2360679774997898

# %%
import math
x = float(input("Введите x: "))
result = math.cos(2*x - 1) + math.sin(x)
print(f"y = {result}")
# Out:
# Введите x:  1
# y = 1.381773290676036

# %%
import math
x = float(input("Введите x: "))
a = float(input("Введите a: "))
b = float(input("Введите b: "))
result = a * math.sqrt(x) + b * x**2
print(f"y = {result}")
# Out:
# Введите x:  1
# Введите a:  1
# Введите b:  1
# y = 2.0
